# %%
"""
+ This is a Test Case for comp_ROOT_fits.py
+ MU,SG,N are not necessarily particular to any FTOF set# (but are inpsired by the general T-distributions)
"""
import comp_ROOT_fits as comp
N=range(100,20000,500)
MU,SG=200,2

# %%
#! First test the program i.e. fit_opt="" should produce same result the default fit option
comp.run(MU,SG,N,NTRIALS=500,fit_opt="",tof_calib=True)

# %%
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True)

# %%
comp.run(MU,SG,N,NTRIALS=500,fit_opt="L",tof_calib=True)
