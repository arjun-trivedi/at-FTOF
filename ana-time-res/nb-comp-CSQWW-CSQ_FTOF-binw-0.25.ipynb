# %%
"""
Demonstrate how parameters extracted for Gaussian T-histogram using ROOT fits depends on
+ N=number of events in this histogram
+ sg=sigma of Gaussian
The paramaters extracted have a very minimal dependence on the mean (see last code block)
"""

# %%
import comp_ROOT_fits as comp
Nlow=range(100,500,20)
Nhigh=range(600,15000,500)
N=Nlow
N.extend(Nhigh)

# %%
MU,SG=190,1
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True,binw=0.25)
# Out:
# /usr/local/lib/python2.7/dist-packages/root_numpy/_root_numpy.py:493: DeprecationWarning: fill_array is deprecated and will be removed. Please use fill_hist instead
#   "Please use fill_hist instead", DeprecationWarning)
# INFO:rootpy.logger] | No default log handler configured. See `logging` module |
# INFO:rootpy.logger] \    To suppress: 'rootpy.log.basic_config_colorized()'   /
# INFO:ROOT.TCanvas.MakeDefCanvas]  created default TCanvas with name c1

# %%
MU,SG=190,2
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True,binw=0.25)

# %%
MU,SG=190,3
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True,binw=0.25)

# %%
MU,SG=190,4
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True,binw=0.25)

# %%
MU,SG=190,5
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True,binw=0.25)

# %%
MU,SG=190,6
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True,binw=0.25)

# %%
#! Show dependence on mean
MU,SG=-500,6
comp.run(MU,SG,N,NTRIALS=500,fit_opt="WW",tof_calib=True,binw=0.25)
